# %%
# Full code for recommendation system with Neural Collaborative Filtering including recipe features

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Flatten, Concatenate, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

recipes_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/recipe_pp.csv')
users_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/user_pp.csv')

# Normalize the recipe features
scaler = MinMaxScaler()
recipes_df[['calories_norm', 'recipe_complexity_norm']] = scaler.fit_transform(
    recipes_df[['calories', 'recipe_complexity']])

# Define the model architecture
num_users = users_df['user_id'].nunique()
num_recipes = recipes_df['recipe_id'].nunique()
embedding_size = 32

user_input = Input(shape=(1,), name='user_input')
user_embedding = Embedding(num_users, embedding_size, name='user_embedding')(user_input)
user_vec = Flatten(name='user_flatten')(user_embedding)

recipe_input = Input(shape=(1,), name='recipe_input')
recipe_embedding = Embedding(num_recipes, embedding_size, name='recipe_embedding')(recipe_input)
recipe_vec = Flatten(name='recipe_flatten')(recipe_embedding)

# Additional recipe features input layer
recipe_features_input = Input(shape=(2,), name='recipe_features_input')

# Combine Embeddings and Features
concat = Concatenate()([user_vec, recipe_vec, recipe_features_input])

# Neural network layers
fc1 = Dense(128, activation='relu')(concat)
fc1_dropout = Dropout(0.5)(fc1)
fc2 = Dense(64, activation='relu')(fc1_dropout)
fc2_dropout = Dropout(0.5)(fc2)
fc3 = Dense(32, activation='relu')(fc2_dropout)
output = Dense(1, activation='sigmoid', name='output')(fc3)

model = Model(inputs=[user_input, recipe_input, recipe_features_input], outputs=output)

model.compile(optimizer=Adam(learning_rate=0.00001), loss='mse', metrics=['mae'])
model.summary()

# Prepare the input data for training
train_user_data = users_df['user_id'].values
train_recipe_data = users_df['recipe_id'].values
# Ensure the recipes_df index is set for proper .loc access
recipes_df.set_index('recipe_id', inplace=True)
train_features_data = recipes_df.loc[train_recipe_data, ['calories_norm', 'recipe_complexity_norm']].values
train_ratings = users_df['rating'].values / users_df['rating'].max()  # Normalizing ratings between 0 and 1

# Train the model
history = model.fit(
    [train_user_data, train_recipe_data, train_features_data],
    train_ratings,
    batch_size=256,
    epochs=6,
    validation_split=0.1,
    verbose=1
)

model.save('/content/drive/MyDrive/ADM Project/data/recipe_recommendation_model3.h5')
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  user_input (InputLayer)     [(None, 1)]                  0         []
#
#  recipe_input (InputLayer)   [(None, 1)]                  0         []
#
#  user_embedding (Embedding)  (None, 1, 32)                7250240   ['user_input[0][0]']
#
#  recipe_embedding (Embeddin  (None, 1, 32)                7412384   ['recipe_input[0][0]']
#  g)
#
#  user_flatten (Flatten)      (None, 32)                   0         ['user_embedding[0][0]']
#
#  recipe_flatten (Flatten)    (None, 32)                   0         ['recipe_embedding[0][0]']
#
#  recipe_features_input (Inp  [(None, 2)]                  0         []
#  utLayer)
#
#  concatenate_10 (Concatenat  (None, 66)                   0         ['user_flatten[0][0]',
#  e)                                                                  'recipe_flatten[0][0]',
#                                                                      'recipe_features_input[0][0]'
#                                                                     ]
#
#  dense_30 (Dense)            (None, 128)                  8576      ['concatenate_10[0][0]']
#
#  dropout_20 (Dropout)        (None, 128)                  0         ['dense_30[0][0]']
#
#  dense_31 (Dense)            (None, 64)                   8256      ['dropout_20[0][0]']
#
#  dropout_21 (Dropout)        (None, 64)                   0         ['dense_31[0][0]']
#
#  dense_32 (Dense)            (None, 32)                   2080      ['dropout_21[0][0]']
#
#  output (Dense)              (None, 1)                    33        ['dense_32[0][0]']
#
# ==================================================================================================
# Total params: 14681569 (56.01 MB)
# Trainable params: 14681569 (56.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/6
# 3981/3981 [==============================] - 24s 6ms/step - loss: 0.1155 - mae: 0.2914 - val_loss: 0.0621 - val_mae: 0.1679
# Epoch 2/6
# 3981/3981 [==============================] - 19s 5ms/step - loss: 0.0655 - mae: 0.1684 - val_loss: 0.0617 - val_mae: 0.1609
# Epoch 3/6
# 3981/3981 [==============================] - 19s 5ms/step - loss: 0.0646 - mae: 0.1666 - val_loss: 0.0612 - val_mae: 0.1628
# Epoch 4/6
# 3981/3981 [==============================] - 19s 5ms/step - loss: 0.0638 - mae: 0.1654 - val_loss: 0.0610 - val_mae: 0.1619
# Epoch 5/6
# 3981/3981 [==============================] - 19s 5ms/step - loss: 0.0632 - mae: 0.1641 - val_loss: 0.0609 - val_mae: 0.1625
# Epoch 6/6
# 3981/3981 [==============================] - 19s 5ms/step - loss: 0.0627 - mae: 0.1628 - val_loss: 0.0609 - val_mae: 0.1627
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Flatten, Concatenate, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

recipes_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/recipe_pp.csv')
users_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/user_pp.csv')

# Normalize the recipe features
scaler = MinMaxScaler()
recipes_df[['calories_norm', 'recipe_complexity_norm']] = scaler.fit_transform(
    recipes_df[['calories', 'recipe_complexity']])

# Define the model architecture
num_users = users_df['user_id'].nunique()
num_recipes = recipes_df['recipe_id'].nunique()
embedding_size = 32

user_input = Input(shape=(1,), name='user_input')
user_embedding = Embedding(num_users, embedding_size, name='user_embedding')(user_input)
user_vec = Flatten(name='user_flatten')(user_embedding)

recipe_input = Input(shape=(1,), name='recipe_input')
recipe_embedding = Embedding(num_recipes, embedding_size, name='recipe_embedding')(recipe_input)
recipe_vec = Flatten(name='recipe_flatten')(recipe_embedding)

# Additional recipe features input layer
recipe_features_input = Input(shape=(2,), name='recipe_features_input')

# Combine Embeddings and Features
concat = Concatenate()([user_vec, recipe_vec, recipe_features_input])

# Neural network layers
fc1 = Dense(128, activation='relu')(concat)
fc1_dropout = Dropout(0.5)(fc1)
fc2 = Dense(64, activation='relu')(fc1_dropout)
fc2_dropout = Dropout(0.5)(fc2)
fc3 = Dense(32, activation='relu')(fc2_dropout)
output = Dense(1, activation='sigmoid', name='output')(fc3)

model = Model(inputs=[user_input, recipe_input, recipe_features_input], outputs=output)

model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
model.summary()

# Prepare the input data for training
train_user_data = users_df['user_id'].values
train_recipe_data = users_df['recipe_id'].values
# Ensure the recipes_df index is set for proper .loc access
recipes_df.set_index('recipe_id', inplace=True)
train_features_data = recipes_df.loc[train_recipe_data, ['calories_norm', 'recipe_complexity_norm']].values
train_ratings = users_df['rating'].values / users_df['rating'].max()  # Normalizing ratings between 0 and 1

# Train the model
history = model.fit(
    [train_user_data, train_recipe_data, train_features_data],
    train_ratings,
    batch_size=256,
    epochs=6,
    validation_split=0.1,
    verbose=1
)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  user_input (InputLayer)     [(None, 1)]                  0         []
#
#  recipe_input (InputLayer)   [(None, 1)]                  0         []
#
#  user_embedding (Embedding)  (None, 1, 32)                7250240   ['user_input[0][0]']
#
#  recipe_embedding (Embeddin  (None, 1, 32)                7412384   ['recipe_input[0][0]']
#  g)
#
#  user_flatten (Flatten)      (None, 32)                   0         ['user_embedding[0][0]']
#
#  recipe_flatten (Flatten)    (None, 32)                   0         ['recipe_embedding[0][0]']
#
#  recipe_features_input (Inp  [(None, 2)]                  0         []
#  utLayer)
#
#  concatenate (Concatenate)   (None, 66)                   0         ['user_flatten[0][0]',
#                                                                      'recipe_flatten[0][0]',
#                                                                      'recipe_features_input[0][0]'
#                                                                     ]
#
#  dense (Dense)               (None, 128)                  8576      ['concatenate[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   8256      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 64)                   0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 32)                   2080      ['dropout_1[0][0]']
#
#  output (Dense)              (None, 1)                    33        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 14681569 (56.01 MB)
# Trainable params: 14681569 (56.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/6
# 3981/3981 [==============================] - 30s 6ms/step - loss: 0.0632 - mae: 0.1635 - val_loss: 0.0605 - val_mae: 0.1650
# Epoch 2/6
# 3981/3981 [==============================] - 18s 5ms/step - loss: 0.0587 - mae: 0.1534 - val_loss: 0.0618 - val_mae: 0.1738
# Epoch 3/6
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0561 - mae: 0.1472 - val_loss: 0.0630 - val_mae: 0.1789
# Epoch 4/6
# 3981/3981 [==============================] - 17s 4ms/step - loss: 0.0544 - mae: 0.1430 - val_loss: 0.0627 - val_mae: 0.1732
# Epoch 5/6
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0532 - mae: 0.1401 - val_loss: 0.0633 - val_mae: 0.1743
# Epoch 6/6
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0524 - mae: 0.1380 - val_loss: 0.0636 - val_mae: 0.1722

# %%
## 2
## 1
# Full code for recommendation system with Neural Collaborative Filtering including recipe features

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Flatten, Concatenate, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

recipes_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/recipe_pp.csv')
users_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/user_pp.csv')

# Normalize the recipe features
scaler = MinMaxScaler()
recipes_df[['calories_norm', 'recipe_complexity_norm']] = scaler.fit_transform(
    recipes_df[['calories', 'recipe_complexity']])

# Define the model architecture
num_users = users_df['user_id'].nunique()
num_recipes = recipes_df['recipe_id'].nunique()
embedding_size = 32

user_input = Input(shape=(1,), name='user_input')
user_embedding = Embedding(num_users, embedding_size, name='user_embedding')(user_input)
user_vec = Flatten(name='user_flatten')(user_embedding)

recipe_input = Input(shape=(1,), name='recipe_input')
recipe_embedding = Embedding(num_recipes, embedding_size, name='recipe_embedding')(recipe_input)
recipe_vec = Flatten(name='recipe_flatten')(recipe_embedding)

# Additional recipe features input layer
recipe_features_input = Input(shape=(2,), name='recipe_features_input')

# Combine Embeddings and Features
concat = Concatenate()([user_vec, recipe_vec, recipe_features_input])

# Neural network layers
fc1 = Dense(128, activation='relu')(concat)
fc1_dropout = Dropout(0.5)(fc1)
fc2 = Dense(64, activation='relu')(fc1_dropout)
fc2_dropout = Dropout(0.5)(fc2)
fc3 = Dense(32, activation='relu')(fc2_dropout)
output = Dense(1, activation='sigmoid', name='output')(fc3)

model = Model(inputs=[user_input, recipe_input, recipe_features_input], outputs=output)

model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])
model.summary()

# Prepare the input data for training
train_user_data = users_df['user_id'].values
train_recipe_data = users_df['recipe_id'].values
# Ensure the recipes_df index is set for proper .loc access
recipes_df.set_index('recipe_id', inplace=True)
train_features_data = recipes_df.loc[train_recipe_data, ['calories_norm', 'recipe_complexity_norm']].values
train_ratings = users_df['rating'].values / users_df['rating'].max()  # Normalizing ratings between 0 and 1

# Train the model
history = model.fit(
    [train_user_data, train_recipe_data, train_features_data],
    train_ratings,
    batch_size=256,
    epochs=10,
    validation_split=0.1,
    verbose=1
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  user_input (InputLayer)     [(None, 1)]                  0         []
#
#  recipe_input (InputLayer)   [(None, 1)]                  0         []
#
#  user_embedding (Embedding)  (None, 1, 32)                7250240   ['user_input[0][0]']
#
#  recipe_embedding (Embeddin  (None, 1, 32)                7412384   ['recipe_input[0][0]']
#  g)
#
#  user_flatten (Flatten)      (None, 32)                   0         ['user_embedding[0][0]']
#
#  recipe_flatten (Flatten)    (None, 32)                   0         ['recipe_embedding[0][0]']
#
#  recipe_features_input (Inp  [(None, 2)]                  0         []
#  utLayer)
#
#  concatenate_1 (Concatenate  (None, 66)                   0         ['user_flatten[0][0]',
#  )                                                                   'recipe_flatten[0][0]',
#                                                                      'recipe_features_input[0][0]'
#                                                                     ]
#
#  dense_3 (Dense)             (None, 128)                  8576      ['concatenate_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 128)                  0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   8256      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 64)                   0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 32)                   2080      ['dropout_3[0][0]']
#
#  output (Dense)              (None, 1)                    33        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 14681569 (56.01 MB)
# Trainable params: 14681569 (56.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/10
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0690 - mae: 0.1769 - val_loss: 0.0607 - val_mae: 0.1627
# Epoch 2/10
# 3981/3981 [==============================] - 18s 5ms/step - loss: 0.0612 - mae: 0.1576 - val_loss: 0.0618 - val_mae: 0.1705
# Epoch 3/10
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0590 - mae: 0.1525 - val_loss: 0.0628 - val_mae: 0.1738
# Epoch 4/10
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0572 - mae: 0.1496 - val_loss: 0.0645 - val_mae: 0.1783
# Epoch 5/10
# 3981/3981 [==============================] - 18s 5ms/step - loss: 0.0560 - mae: 0.1476 - val_loss: 0.0660 - val_mae: 0.1820
# Epoch 6/10
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0551 - mae: 0.1459 - val_loss: 0.0674 - val_mae: 0.1867
# Epoch 7/10
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0544 - mae: 0.1442 - val_loss: 0.0680 - val_mae: 0.1875
# Epoch 8/10
# 3981/3981 [==============================] - 18s 5ms/step - loss: 0.0538 - mae: 0.1429 - val_loss: 0.0692 - val_mae: 0.1913
# Epoch 9/10
# 3981/3981 [==============================] - 18s 5ms/step - loss: 0.0534 - mae: 0.1418 - val_loss: 0.0693 - val_mae: 0.1926
# Epoch 10/10
# 3981/3981 [==============================] - 18s 5ms/step - loss: 0.0530 - mae: 0.1409 - val_loss: 0.0716 - val_mae: 0.1989

# %%
## 3 LR
## 2
## 1
# Full code for recommendation system with Neural Collaborative Filtering including recipe features

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Flatten, Concatenate, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

# Load the datasets
recipes_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/recipe_pp.csv')
users_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/user_pp.csv')

# Normalize the recipe features
scaler = MinMaxScaler()
recipes_df[['calories_norm', 'recipe_complexity_norm']] = scaler.fit_transform(
    recipes_df[['calories', 'recipe_complexity']])

# Define the model architecture
num_users = users_df['user_id'].nunique()
num_recipes = recipes_df['recipe_id'].nunique()
embedding_size = 32

user_input = Input(shape=(1,), name='user_input')
user_embedding = Embedding(num_users, embedding_size, name='user_embedding')(user_input)
user_vec = Flatten(name='user_flatten')(user_embedding)

recipe_input = Input(shape=(1,), name='recipe_input')
recipe_embedding = Embedding(num_recipes, embedding_size, name='recipe_embedding')(recipe_input)
recipe_vec = Flatten(name='recipe_flatten')(recipe_embedding)

# Additional recipe features input layer
recipe_features_input = Input(shape=(2,), name='recipe_features_input')

# Combine Embeddings and Features
concat = Concatenate()([user_vec, recipe_vec, recipe_features_input])

# Neural network layers
fc1 = Dense(128, activation='relu')(concat)
fc1_dropout = Dropout(0.5)(fc1)
fc2 = Dense(64, activation='relu')(fc1_dropout)
fc2_dropout = Dropout(0.5)(fc2)
fc3 = Dense(32, activation='relu')(fc2_dropout)
output = Dense(1, activation='sigmoid', name='output')(fc3)

model = Model(inputs=[user_input, recipe_input, recipe_features_input], outputs=output)

model.compile(optimizer=Adam(learning_rate=0.00001), loss='mse', metrics=['mae'])
model.summary()

# Prepare the input data for training
train_user_data = users_df['user_id'].values
train_recipe_data = users_df['recipe_id'].values
# Ensure the recipes_df index is set for proper .loc access
recipes_df.set_index('recipe_id', inplace=True)
train_features_data = recipes_df.loc[train_recipe_data, ['calories_norm', 'recipe_complexity_norm']].values
train_ratings = users_df['rating'].values / users_df['rating'].max()  # Normalizing ratings between 0 and 1

# Train the model
history = model.fit(
    [train_user_data, train_recipe_data, train_features_data],
    train_ratings,
    batch_size=256,
    epochs=15,
    validation_split=0.1,
    verbose=1
)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  user_input (InputLayer)     [(None, 1)]                  0         []
#
#  recipe_input (InputLayer)   [(None, 1)]                  0         []
#
#  user_embedding (Embedding)  (None, 1, 32)                7250240   ['user_input[0][0]']
#
#  recipe_embedding (Embeddin  (None, 1, 32)                7412384   ['recipe_input[0][0]']
#  g)
#
#  user_flatten (Flatten)      (None, 32)                   0         ['user_embedding[0][0]']
#
#  recipe_flatten (Flatten)    (None, 32)                   0         ['recipe_embedding[0][0]']
#
#  recipe_features_input (Inp  [(None, 2)]                  0         []
#  utLayer)
#
#  concatenate_2 (Concatenate  (None, 66)                   0         ['user_flatten[0][0]',
#  )                                                                   'recipe_flatten[0][0]',
#                                                                      'recipe_features_input[0][0]'
#                                                                     ]
#
#  dense_6 (Dense)             (None, 128)                  8576      ['concatenate_2[0][0]']
#
#  dropout_4 (Dropout)         (None, 128)                  0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 64)                   8256      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 64)                   0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 32)                   2080      ['dropout_5[0][0]']
#
#  output (Dense)              (None, 1)                    33        ['dense_8[0][0]']
#
# ==================================================================================================
# Total params: 14681569 (56.01 MB)
# Trainable params: 14681569 (56.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/15
# 3981/3981 [==============================] - 23s 5ms/step - loss: 0.1195 - mae: 0.2995 - val_loss: 0.0622 - val_mae: 0.1708
# Epoch 2/15
# 3981/3981 [==============================] - 18s 5ms/step - loss: 0.0653 - mae: 0.1687 - val_loss: 0.0618 - val_mae: 0.1628
# Epoch 3/15
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0645 - mae: 0.1667 - val_loss: 0.0613 - val_mae: 0.1638
# Epoch 4/15
# 3981/3981 [==============================] - 18s 5ms/step - loss: 0.0637 - mae: 0.1655 - val_loss: 0.0611 - val_mae: 0.1632
# Epoch 5/15
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0630 - mae: 0.1640 - val_loss: 0.0610 - val_mae: 0.1641
# Epoch 6/15
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0625 - mae: 0.1626 - val_loss: 0.0610 - val_mae: 0.1633
# Epoch 7/15
# 3981/3981 [==============================] - 18s 5ms/step - loss: 0.0620 - mae: 0.1611 - val_loss: 0.0611 - val_mae: 0.1646
# Epoch 8/15
# 3981/3981 [==============================] - 18s 4ms/step - loss: 0.0615 - mae: 0.1597 - val_loss: 0.0613 - val_mae: 0.1652
# Epoch 9/15
# 1098/3981 [=======>......................] - ETA: 12s - loss: 0.0616 - mae: 0.1592
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5a4ef22aa8b8> in <cell line: 63>()
#      61
#      62 # Train the model
# ---> 63 history = model.fit(
#      64     [train_user_data, train_recipe_data, train_features_data],
#      65     train_ratings,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1781                         ):
#    1782                             callbacks.on_train_batch_begin(step)
# -> 1783                             tmp_logs = self.train_function(iterator)
#    1784                             if data_handler.should_sync:
#    1785                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     829
#     830       with OptionalXlaContext(self._jit_compile):
# --> 831         result = self._call(*args, **kwds)
#     832
#     833       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     865       # In this case we have created variables on the first call, so we run the
#     866       # defunned version which is guaranteed to never create variables.
# --> 867       return tracing_compilation.call_function(
#     868           args, kwds, self._no_variable_creation_config
#     869       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1262         and executing_eagerly):
#    1263       # No tape is watching; skip to running the function.
# -> 1264       return self._inference_function.flat_call(args)
#    1265     forward_backward = self._select_forward_and_backward_functions(
#    1266         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in flat_call(self, args)
#     215   def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216     """Calls with tensor inputs and returns the structured output."""
# --> 217     flat_outputs = self(*args)
#     218     return self.function_type.pack_output(flat_outputs)
#     219
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in __call__(self, *args)
#     250         with record.stop_recording():
#     251           if self._bound_context.executing_eagerly():
# --> 252             outputs = self._bound_context.call_function(
#     253                 self.name,
#     254                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1477     cancellation_context = cancellation.context()
#    1478     if cancellation_context is None:
# -> 1479       outputs = execute.execute(
#    1480           name.decode("utf-8"),
#    1481           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
## 3 LR
## 2
## 1
# Full code for recommendation system with Neural Collaborative Filtering including recipe features

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Flatten, Concatenate, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

# Load the datasets
recipes_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/recipe_pp.csv')
users_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/user_pp.csv')

# Normalize the recipe features
scaler = MinMaxScaler()
recipes_df[['calories_norm', 'recipe_complexity_norm']] = scaler.fit_transform(
    recipes_df[['calories', 'recipe_complexity']])

# Define the model architecture
num_users = users_df['user_id'].nunique()
num_recipes = recipes_df['recipe_id'].nunique()
embedding_size = 64

user_input = Input(shape=(1,), name='user_input')
user_embedding = Embedding(num_users, embedding_size, name='user_embedding')(user_input)
user_vec = Flatten(name='user_flatten')(user_embedding)

recipe_input = Input(shape=(1,), name='recipe_input')
recipe_embedding = Embedding(num_recipes, embedding_size, name='recipe_embedding')(recipe_input)
recipe_vec = Flatten(name='recipe_flatten')(recipe_embedding)

# Additional recipe features input layer
recipe_features_input = Input(shape=(2,), name='recipe_features_input')

# Combine Embeddings and Features
concat = Concatenate()([user_vec, recipe_vec, recipe_features_input])

# Neural network layers
fc1 = Dense(128, activation='relu')(concat)
fc1_dropout = Dropout(0.5)(fc1)
fc2 = Dense(64, activation='relu')(fc1_dropout)
fc2_dropout = Dropout(0.5)(fc2)
fc3 = Dense(32, activation='relu')(fc2_dropout)
output = Dense(1, activation='sigmoid', name='output')(fc3)

model = Model(inputs=[user_input, recipe_input, recipe_features_input], outputs=output)

model.compile(optimizer=Adam(learning_rate=0.00001), loss='mse', metrics=['mae'])
model.summary()

# Prepare the input data for training
train_user_data = users_df['user_id'].values
train_recipe_data = users_df['recipe_id'].values
# Ensure the recipes_df index is set for proper .loc access
recipes_df.set_index('recipe_id', inplace=True)
train_features_data = recipes_df.loc[train_recipe_data, ['calories_norm', 'recipe_complexity_norm']].values
train_ratings = users_df['rating'].values / users_df['rating'].max()  # Normalizing ratings between 0 and 1

# Train the model
history = model.fit(
    [train_user_data, train_recipe_data, train_features_data],
    train_ratings,
    batch_size=256,
    epochs=15,
    validation_split=0.1,
    verbose=1
)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  user_input (InputLayer)     [(None, 1)]                  0         []
#
#  recipe_input (InputLayer)   [(None, 1)]                  0         []
#
#  user_embedding (Embedding)  (None, 1, 64)                1450048   ['user_input[0][0]']
#                                                           0
#
#  recipe_embedding (Embeddin  (None, 1, 64)                1482476   ['recipe_input[0][0]']
#  g)                                                       8
#
#  user_flatten (Flatten)      (None, 64)                   0         ['user_embedding[0][0]']
#
#  recipe_flatten (Flatten)    (None, 64)                   0         ['recipe_embedding[0][0]']
#
#  recipe_features_input (Inp  [(None, 2)]                  0         []
#  utLayer)
#
#  concatenate_3 (Concatenate  (None, 130)                  0         ['user_flatten[0][0]',
#  )                                                                   'recipe_flatten[0][0]',
#                                                                      'recipe_features_input[0][0]'
#                                                                     ]
#
#  dense_9 (Dense)             (None, 128)                  16768     ['concatenate_3[0][0]']
#
#  dropout_6 (Dropout)         (None, 128)                  0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 64)                   8256      ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 64)                   0         ['dense_10[0][0]']
#
#  dense_11 (Dense)            (None, 32)                   2080      ['dropout_7[0][0]']
#
#  output (Dense)              (None, 1)                    33        ['dense_11[0][0]']
#
# ==================================================================================================
# Total params: 29352385 (111.97 MB)
# Trainable params: 29352385 (111.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/15
# 3981/3981 [==============================] - 28s 7ms/step - loss: 0.1139 - mae: 0.2884 - val_loss: 0.0618 - val_mae: 0.1684
# Epoch 2/15
# 3981/3981 [==============================] - 21s 5ms/step - loss: 0.0651 - mae: 0.1679 - val_loss: 0.0614 - val_mae: 0.1618
# Epoch 3/15
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0642 - mae: 0.1658 - val_loss: 0.0610 - val_mae: 0.1624
# Epoch 4/15
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0634 - mae: 0.1643 - val_loss: 0.0608 - val_mae: 0.1624
# Epoch 5/15
# 3981/3981 [==============================] - 21s 5ms/step - loss: 0.0628 - mae: 0.1627 - val_loss: 0.0608 - val_mae: 0.1631
# Epoch 6/15
# 3981/3981 [==============================] - 22s 6ms/step - loss: 0.0622 - mae: 0.1612 - val_loss: 0.0609 - val_mae: 0.1636
# Epoch 7/15
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0616 - mae: 0.1596 - val_loss: 0.0611 - val_mae: 0.1652
# Epoch 8/15
# 3981/3981 [==============================] - 22s 6ms/step - loss: 0.0611 - mae: 0.1582 - val_loss: 0.0613 - val_mae: 0.1659
# Epoch 9/15
# 3981/3981 [==============================] - 21s 5ms/step - loss: 0.0606 - mae: 0.1567 - val_loss: 0.0616 - val_mae: 0.1675
# Epoch 10/15
# 3981/3981 [==============================] - 21s 5ms/step - loss: 0.0601 - mae: 0.1553 - val_loss: 0.0619 - val_mae: 0.1686
# Epoch 11/15
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0596 - mae: 0.1539 - val_loss: 0.0623 - val_mae: 0.1697
# Epoch 12/15
# 3981/3981 [==============================] - 21s 5ms/step - loss: 0.0591 - mae: 0.1526 - val_loss: 0.0626 - val_mae: 0.1704
# Epoch 13/15
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0587 - mae: 0.1513 - val_loss: 0.0632 - val_mae: 0.1726
# Epoch 14/15
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0583 - mae: 0.1503 - val_loss: 0.0637 - val_mae: 0.1738
# Epoch 15/15
# 3981/3981 [==============================] - 21s 5ms/step - loss: 0.0579 - mae: 0.1493 - val_loss: 0.0641 - val_mae: 0.1747

# %%
## 3 LR
## 2
## 1
# Full code for recommendation system with Neural Collaborative Filtering including recipe features

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Flatten, Concatenate, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

# Load the datasets
recipes_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/recipe_pp.csv')
users_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/user_pp.csv')

# Normalize the recipe features
scaler = MinMaxScaler()
recipes_df[['calories_norm', 'recipe_complexity_norm']] = scaler.fit_transform(
    recipes_df[['calories', 'recipe_complexity']])

# Define the model architecture
num_users = users_df['user_id'].nunique()
num_recipes = recipes_df['recipe_id'].nunique()
embedding_size = 128

user_input = Input(shape=(1,), name='user_input')
user_embedding = Embedding(num_users, embedding_size, name='user_embedding')(user_input)
user_vec = Flatten(name='user_flatten')(user_embedding)

recipe_input = Input(shape=(1,), name='recipe_input')
recipe_embedding = Embedding(num_recipes, embedding_size, name='recipe_embedding')(recipe_input)
recipe_vec = Flatten(name='recipe_flatten')(recipe_embedding)

# Additional recipe features input layer
recipe_features_input = Input(shape=(2,), name='recipe_features_input')

# Combine Embeddings and Features
concat = Concatenate()([user_vec, recipe_vec, recipe_features_input])

# Neural network layers
fc1 = Dense(128, activation='relu')(concat)
fc1_dropout = Dropout(0.5)(fc1)
fc2 = Dense(64, activation='relu')(fc1_dropout)
fc2_dropout = Dropout(0.5)(fc2)
fc3 = Dense(32, activation='relu')(fc2_dropout)
output = Dense(1, activation='sigmoid', name='output')(fc3)

model = Model(inputs=[user_input, recipe_input, recipe_features_input], outputs=output)

model.compile(optimizer=Adam(learning_rate=0.00001), loss='mse', metrics=['mae'])
model.summary()

# Prepare the input data for training
train_user_data = users_df['user_id'].values
train_recipe_data = users_df['recipe_id'].values
# Ensure the recipes_df index is set for proper .loc access
recipes_df.set_index('recipe_id', inplace=True)
train_features_data = recipes_df.loc[train_recipe_data, ['calories_norm', 'recipe_complexity_norm']].values
train_ratings = users_df['rating'].values / users_df['rating'].max()

# Train the model
history = model.fit(
    [train_user_data, train_recipe_data, train_features_data],
    train_ratings,
    batch_size=256,
    epochs=10,
    validation_split=0.1,
    verbose=1
)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  user_input (InputLayer)     [(None, 1)]                  0         []
#
#  recipe_input (InputLayer)   [(None, 1)]                  0         []
#
#  user_embedding (Embedding)  (None, 1, 128)               2900096   ['user_input[0][0]']
#                                                           0
#
#  recipe_embedding (Embeddin  (None, 1, 128)               2964953   ['recipe_input[0][0]']
#  g)                                                       6
#
#  user_flatten (Flatten)      (None, 128)                  0         ['user_embedding[0][0]']
#
#  recipe_flatten (Flatten)    (None, 128)                  0         ['recipe_embedding[0][0]']
#
#  recipe_features_input (Inp  [(None, 2)]                  0         []
#  utLayer)
#
#  concatenate_4 (Concatenate  (None, 258)                  0         ['user_flatten[0][0]',
#  )                                                                   'recipe_flatten[0][0]',
#                                                                      'recipe_features_input[0][0]'
#                                                                     ]
#
#  dense_12 (Dense)            (None, 128)                  33152     ['concatenate_4[0][0]']
#
#  dropout_8 (Dropout)         (None, 128)                  0         ['dense_12[0][0]']
#
#  dense_13 (Dense)            (None, 64)                   8256      ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 64)                   0         ['dense_13[0][0]']
#
#  dense_14 (Dense)            (None, 32)                   2080      ['dropout_9[0][0]']
#
#  output (Dense)              (None, 1)                    33        ['dense_14[0][0]']
#
# ==================================================================================================
# Total params: 58694017 (223.90 MB)
# Trainable params: 58694017 (223.90 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/10
# 3981/3981 [==============================] - 33s 8ms/step - loss: 0.1143 - mae: 0.2892 - val_loss: 0.0617 - val_mae: 0.1680
# Epoch 2/10
# 3981/3981 [==============================] - 29s 7ms/step - loss: 0.0646 - mae: 0.1669 - val_loss: 0.0612 - val_mae: 0.1625
# Epoch 3/10
# 3981/3981 [==============================] - 28s 7ms/step - loss: 0.0636 - mae: 0.1645 - val_loss: 0.0609 - val_mae: 0.1618
# Epoch 4/10
# 3981/3981 [==============================] - 29s 7ms/step - loss: 0.0628 - mae: 0.1626 - val_loss: 0.0609 - val_mae: 0.1630
# Epoch 5/10
# 3981/3981 [==============================] - 29s 7ms/step - loss: 0.0621 - mae: 0.1608 - val_loss: 0.0610 - val_mae: 0.1640
# Epoch 6/10
# 3981/3981 [==============================] - 29s 7ms/step - loss: 0.0614 - mae: 0.1590 - val_loss: 0.0612 - val_mae: 0.1652
# Epoch 7/10
# 3981/3981 [==============================] - 29s 7ms/step - loss: 0.0608 - mae: 0.1573 - val_loss: 0.0615 - val_mae: 0.1667
# Epoch 8/10
# 3981/3981 [==============================] - 29s 7ms/step - loss: 0.0602 - mae: 0.1556 - val_loss: 0.0618 - val_mae: 0.1674
# Epoch 9/10
# 3981/3981 [==============================] - 29s 7ms/step - loss: 0.0596 - mae: 0.1540 - val_loss: 0.0624 - val_mae: 0.1701
# Epoch 10/10
# 3981/3981 [==============================] - 29s 7ms/step - loss: 0.0591 - mae: 0.1524 - val_loss: 0.0628 - val_mae: 0.1714

# %%
## 3 LR
## 2
## 1
# Full code for recommendation system with Neural Collaborative Filtering including recipe features

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Flatten, Concatenate, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

# Load the datasets
recipes_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/recipe_pp.csv')
users_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/user_pp.csv')

# Normalize the recipe features
scaler = MinMaxScaler()
recipes_df[['calories_norm', 'recipe_complexity_norm']] = scaler.fit_transform(
    recipes_df[['calories', 'recipe_complexity']])

# Define the model architecture
num_users = users_df['user_id'].nunique()
num_recipes = recipes_df['recipe_id'].nunique()
embedding_size = 64

user_input = Input(shape=(1,), name='user_input')
user_embedding = Embedding(num_users, embedding_size, name='user_embedding')(user_input)
user_vec = Flatten(name='user_flatten')(user_embedding)

recipe_input = Input(shape=(1,), name='recipe_input')
recipe_embedding = Embedding(num_recipes, embedding_size, name='recipe_embedding')(recipe_input)
recipe_vec = Flatten(name='recipe_flatten')(recipe_embedding)

# Additional recipe features input layer
recipe_features_input = Input(shape=(2,), name='recipe_features_input')

# Combine Embeddings and Features
concat = Concatenate()([user_vec, recipe_vec, recipe_features_input])

# Neural network layers
fc1 = Dense(128, activation='relu')(concat)
fc1_dropout = Dropout(0.7)(fc1)
fc2 = Dense(64, activation='relu')(fc1_dropout)
fc2_dropout = Dropout(0.7)(fc2)
fc3 = Dense(32, activation='relu')(fc2_dropout)
output = Dense(1, activation='sigmoid', name='output')(fc3)

model = Model(inputs=[user_input, recipe_input, recipe_features_input], outputs=output)

model.compile(optimizer=Adam(learning_rate=0.00001), loss='mse', metrics=['mae'])
model.summary()

# Prepare the input data for training
train_user_data = users_df['user_id'].values
train_recipe_data = users_df['recipe_id'].values
# Ensure the recipes_df index is set for proper .loc access
recipes_df.set_index('recipe_id', inplace=True)
train_features_data = recipes_df.loc[train_recipe_data, ['calories_norm', 'recipe_complexity_norm']].values
train_ratings = users_df['rating'].values / users_df['rating'].max()
# Train the model
history = model.fit(
    [train_user_data, train_recipe_data, train_features_data],
    train_ratings,
    batch_size=256,
    epochs=7,
    validation_split=0.1,
    verbose=1
)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  user_input (InputLayer)     [(None, 1)]                  0         []
#
#  recipe_input (InputLayer)   [(None, 1)]                  0         []
#
#  user_embedding (Embedding)  (None, 1, 64)                1450048   ['user_input[0][0]']
#                                                           0
#
#  recipe_embedding (Embeddin  (None, 1, 64)                1482476   ['recipe_input[0][0]']
#  g)                                                       8
#
#  user_flatten (Flatten)      (None, 64)                   0         ['user_embedding[0][0]']
#
#  recipe_flatten (Flatten)    (None, 64)                   0         ['recipe_embedding[0][0]']
#
#  recipe_features_input (Inp  [(None, 2)]                  0         []
#  utLayer)
#
#  concatenate_5 (Concatenate  (None, 130)                  0         ['user_flatten[0][0]',
#  )                                                                   'recipe_flatten[0][0]',
#                                                                      'recipe_features_input[0][0]'
#                                                                     ]
#
#  dense_15 (Dense)            (None, 128)                  16768     ['concatenate_5[0][0]']
#
#  dropout_10 (Dropout)        (None, 128)                  0         ['dense_15[0][0]']
#
#  dense_16 (Dense)            (None, 64)                   8256      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 64)                   0         ['dense_16[0][0]']
#
#  dense_17 (Dense)            (None, 32)                   2080      ['dropout_11[0][0]']
#
#  output (Dense)              (None, 1)                    33        ['dense_17[0][0]']
#
# ==================================================================================================
# Total params: 29352385 (111.97 MB)
# Trainable params: 29352385 (111.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/7
# 3981/3981 [==============================] - 26s 6ms/step - loss: 0.1513 - mae: 0.3594 - val_loss: 0.0668 - val_mae: 0.1973
# Epoch 2/7
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0700 - mae: 0.1797 - val_loss: 0.0630 - val_mae: 0.1521
# Epoch 3/7
# 3981/3981 [==============================] - 21s 5ms/step - loss: 0.0674 - mae: 0.1655 - val_loss: 0.0620 - val_mae: 0.1555
# Epoch 4/7
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0660 - mae: 0.1656 - val_loss: 0.0614 - val_mae: 0.1578
# Epoch 5/7
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0649 - mae: 0.1650 - val_loss: 0.0611 - val_mae: 0.1591
# Epoch 6/7
# 3981/3981 [==============================] - 21s 5ms/step - loss: 0.0641 - mae: 0.1640 - val_loss: 0.0609 - val_mae: 0.1599
# Epoch 7/7
# 3981/3981 [==============================] - 22s 5ms/step - loss: 0.0634 - mae: 0.1628 - val_loss: 0.0609 - val_mae: 0.1606

# %%
## 3 LR
## 2
## 1
# Full code for recommendation system with Neural Collaborative Filtering including recipe features

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Flatten, Concatenate, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

# Load the datasets
recipes_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/recipe_pp.csv')
users_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/user_pp.csv')

# Normalize the recipe features
scaler = MinMaxScaler()
recipes_df[['calories_norm', 'recipe_complexity_norm']] = scaler.fit_transform(
    recipes_df[['calories', 'recipe_complexity']])

# Define the model architecture
num_users = users_df['user_id'].nunique()
num_recipes = recipes_df['recipe_id'].nunique()
embedding_size = 64

user_input = Input(shape=(1,), name='user_input')
user_embedding = Embedding(num_users, embedding_size, name='user_embedding')(user_input)
user_vec = Flatten(name='user_flatten')(user_embedding)

recipe_input = Input(shape=(1,), name='recipe_input')
recipe_embedding = Embedding(num_recipes, embedding_size, name='recipe_embedding')(recipe_input)
recipe_vec = Flatten(name='recipe_flatten')(recipe_embedding)

# Additional recipe features input layer
recipe_features_input = Input(shape=(2,), name='recipe_features_input')

# Combine Embeddings and Features
concat = Concatenate()([user_vec, recipe_vec, recipe_features_input])

# Neural network layers
fc1 = Dense(128, activation='relu')(concat)
fc1_dropout = Dropout(0.7)(fc1)
fc2 = Dense(64, activation='relu')(fc1_dropout)
fc2_dropout = Dropout(0.7)(fc2)
fc3 = Dense(32, activation='relu')(fc2_dropout)
output = Dense(1, activation='sigmoid', name='output')(fc3)

model = Model(inputs=[user_input, recipe_input, recipe_features_input], outputs=output)

model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])
model.summary()

# Prepare the input data for training
train_user_data = users_df['user_id'].values
train_recipe_data = users_df['recipe_id'].values
# Ensure the recipes_df index is set for proper .loc access
recipes_df.set_index('recipe_id', inplace=True)
train_features_data = recipes_df.loc[train_recipe_data, ['calories_norm', 'recipe_complexity_norm']].values
train_ratings = users_df['rating'].values / users_df['rating'].max()

# Train the model
history = model.fit(
    [train_user_data, train_recipe_data, train_features_data],
    train_ratings,
    batch_size=128,
    epochs=7,
    validation_split=0.1,
    verbose=1
)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  user_input (InputLayer)     [(None, 1)]                  0         []
#
#  recipe_input (InputLayer)   [(None, 1)]                  0         []
#
#  user_embedding (Embedding)  (None, 1, 64)                1450048   ['user_input[0][0]']
#                                                           0
#
#  recipe_embedding (Embeddin  (None, 1, 64)                1482476   ['recipe_input[0][0]']
#  g)                                                       8
#
#  user_flatten (Flatten)      (None, 64)                   0         ['user_embedding[0][0]']
#
#  recipe_flatten (Flatten)    (None, 64)                   0         ['recipe_embedding[0][0]']
#
#  recipe_features_input (Inp  [(None, 2)]                  0         []
#  utLayer)
#
#  concatenate_6 (Concatenate  (None, 130)                  0         ['user_flatten[0][0]',
#  )                                                                   'recipe_flatten[0][0]',
#                                                                      'recipe_features_input[0][0]'
#                                                                     ]
#
#  dense_18 (Dense)            (None, 128)                  16768     ['concatenate_6[0][0]']
#
#  dropout_12 (Dropout)        (None, 128)                  0         ['dense_18[0][0]']
#
#  dense_19 (Dense)            (None, 64)                   8256      ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)        (None, 64)                   0         ['dense_19[0][0]']
#
#  dense_20 (Dense)            (None, 32)                   2080      ['dropout_13[0][0]']
#
#  output (Dense)              (None, 1)                    33        ['dense_20[0][0]']
#
# ==================================================================================================
# Total params: 29352385 (111.97 MB)
# Trainable params: 29352385 (111.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/7
# 7962/7962 [==============================] - 47s 6ms/step - loss: 0.0697 - mae: 0.1744 - val_loss: 0.0607 - val_mae: 0.1627
# Epoch 2/7
# 7962/7962 [==============================] - 43s 5ms/step - loss: 0.0614 - mae: 0.1573 - val_loss: 0.0613 - val_mae: 0.1683
# Epoch 3/7
# 7962/7962 [==============================] - 42s 5ms/step - loss: 0.0596 - mae: 0.1527 - val_loss: 0.0626 - val_mae: 0.1757
# Epoch 4/7
# 7962/7962 [==============================] - 43s 5ms/step - loss: 0.0581 - mae: 0.1506 - val_loss: 0.0647 - val_mae: 0.1828
# Epoch 5/7
# 7962/7962 [==============================] - 43s 5ms/step - loss: 0.0570 - mae: 0.1490 - val_loss: 0.0663 - val_mae: 0.1865
# Epoch 6/7
# 7962/7962 [==============================] - 43s 5ms/step - loss: 0.0563 - mae: 0.1476 - val_loss: 0.0679 - val_mae: 0.1905
# Epoch 7/7
# 7962/7962 [==============================] - 43s 5ms/step - loss: 0.0557 - mae: 0.1462 - val_loss: 0.0686 - val_mae: 0.1935

# %%
## 3 LR
## 2
## 1
# Full code for recommendation system with Neural Collaborative Filtering including recipe features

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, Flatten, Concatenate, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

# Load the datasets
recipes_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/recipe_pp.csv')
users_df = pd.read_csv('/content/drive/MyDrive/ADM Project/data/user_pp.csv')

# Normalize the recipe features
scaler = MinMaxScaler()
recipes_df[['calories_norm', 'recipe_complexity_norm']] = scaler.fit_transform(
    recipes_df[['calories', 'recipe_complexity']])

# Define the model architecture
num_users = users_df['user_id'].nunique()
num_recipes = recipes_df['recipe_id'].nunique()
embedding_size = 64

user_input = Input(shape=(1,), name='user_input')
user_embedding = Embedding(num_users, embedding_size, name='user_embedding')(user_input)
user_vec = Flatten(name='user_flatten')(user_embedding)

recipe_input = Input(shape=(1,), name='recipe_input')
recipe_embedding = Embedding(num_recipes, embedding_size, name='recipe_embedding')(recipe_input)
recipe_vec = Flatten(name='recipe_flatten')(recipe_embedding)

# Additional recipe features input layer
recipe_features_input = Input(shape=(2,), name='recipe_features_input')

# Combine Embeddings and Features
concat = Concatenate()([user_vec, recipe_vec, recipe_features_input])

# Neural network layers
fc1 = Dense(128, activation='relu')(concat)
fc1_dropout = Dropout(0.7)(fc1)
fc2 = Dense(64, activation='relu')(fc1_dropout)
fc2_dropout = Dropout(0.7)(fc2)
fc3 = Dense(32, activation='relu')(fc2_dropout)
output = Dense(1, activation='sigmoid', name='output')(fc3)

model = Model(inputs=[user_input, recipe_input, recipe_features_input], outputs=output)

model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse', metrics=['mae'])
model.summary()

# Prepare the input data for training
train_user_data = users_df['user_id'].values
train_recipe_data = users_df['recipe_id'].values
# Ensure the recipes_df index is set for proper .loc access
recipes_df.set_index('recipe_id', inplace=True)
train_features_data = recipes_df.loc[train_recipe_data, ['calories_norm', 'recipe_complexity_norm']].values
train_ratings = users_df['rating'].values / users_df['rating'].max()

# Train the model
history = model.fit(
    [train_user_data, train_recipe_data, train_features_data],
    train_ratings,
    batch_size=512,
    epochs=7,
    validation_split=0.1,
    verbose=1
)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  user_input (InputLayer)     [(None, 1)]                  0         []
#
#  recipe_input (InputLayer)   [(None, 1)]                  0         []
#
#  user_embedding (Embedding)  (None, 1, 64)                1450048   ['user_input[0][0]']
#                                                           0
#
#  recipe_embedding (Embeddin  (None, 1, 64)                1482476   ['recipe_input[0][0]']
#  g)                                                       8
#
#  user_flatten (Flatten)      (None, 64)                   0         ['user_embedding[0][0]']
#
#  recipe_flatten (Flatten)    (None, 64)                   0         ['recipe_embedding[0][0]']
#
#  recipe_features_input (Inp  [(None, 2)]                  0         []
#  utLayer)
#
#  concatenate_7 (Concatenate  (None, 130)                  0         ['user_flatten[0][0]',
#  )                                                                   'recipe_flatten[0][0]',
#                                                                      'recipe_features_input[0][0]'
#                                                                     ]
#
#  dense_21 (Dense)            (None, 128)                  16768     ['concatenate_7[0][0]']
#
#  dropout_14 (Dropout)        (None, 128)                  0         ['dense_21[0][0]']
#
#  dense_22 (Dense)            (None, 64)                   8256      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 64)                   0         ['dense_22[0][0]']
#
#  dense_23 (Dense)            (None, 32)                   2080      ['dropout_15[0][0]']
#
#  output (Dense)              (None, 1)                    33        ['dense_23[0][0]']
#
# ==================================================================================================
# Total params: 29352385 (111.97 MB)
# Trainable params: 29352385 (111.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/7
# 1991/1991 [==============================] - 21s 10ms/step - loss: 0.0806 - mae: 0.1982 - val_loss: 0.0609 - val_mae: 0.1561
# Epoch 2/7
# 1991/1991 [==============================] - 12s 6ms/step - loss: 0.0633 - mae: 0.1595 - val_loss: 0.0612 - val_mae: 0.1614
# Epoch 3/7
# 1991/1991 [==============================] - 11s 5ms/step - loss: 0.0607 - mae: 0.1536 - val_loss: 0.0620 - val_mae: 0.1663
# Epoch 4/7
# 1991/1991 [==============================] - 11s 6ms/step - loss: 0.0587 - mae: 0.1491 - val_loss: 0.0630 - val_mae: 0.1710
# Epoch 5/7
# 1991/1991 [==============================] - 11s 6ms/step - loss: 0.0573 - mae: 0.1463 - val_loss: 0.0638 - val_mae: 0.1750
# Epoch 6/7
# 1991/1991 [==============================] - 11s 6ms/step - loss: 0.0562 - mae: 0.1449 - val_loss: 0.0642 - val_mae: 0.1779
# Epoch 7/7
# 1991/1991 [==============================] - 11s 5ms/step - loss: 0.0552 - mae: 0.1440 - val_loss: 0.0639 - val_mae: 0.1766
